# %% [markdown]
# ### Correlations for CO2/GDP/Pop

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as pl

# %% [markdown]
# Read in data file

# %%
df=pd.read_csv('CO2_pivot_noCO2_930.csv')

# Remove all 2020 rows
df=df.drop(df[df['Year'] == 2020].index)

df
# Out:
#       Unnamed: 0 Country Name  Year  \
# 0              0  Afghanistan  2004
# 1              1  Afghanistan  2005
# 2              2  Afghanistan  2006
# 3              3  Afghanistan  2007
# 4              4  Afghanistan  2008
# ...          ...          ...   ...
# 4057        4499     Zimbabwe  2015
# 4058        4500     Zimbabwe  2016
# 4059        4501     Zimbabwe  2017
# 4060        4502     Zimbabwe  2018
# 4061        4503     Zimbabwe  2019
#
#       ARI treatment (% of children under 5 taken to a health provider)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4057                                               50.9
# 4058                                                NaN
# 4059                                                NaN
# 4060                                                NaN
# 4061                                               48.0
#
#       Access to clean fuels and technologies for cooking (% of population)  \
# 0                                                  10.5
# 1                                                  11.9
# 2                                                  13.5
# 3                                                  15.1
# 4                                                  16.6
# ...                                                 ...
# 4057                                               30.0
# 4058                                               30.0
# 4059                                               30.1
# 4060                                               30.3
# 4061                                               30.3
#
#       Access to clean fuels and technologies for cooking, rural (% of rural population)  \
# 0                                                   1.9
# 1                                                   2.4
# 2                                                   3.0
# 3                                                   3.6
# 4                                                   4.3
# ...                                                 ...
# 4057                                                5.8
# 4058                                                6.0
# 4059                                                6.1
# 4060                                                6.5
# 4061                                                6.7
#
#       Access to clean fuels and technologies for cooking, urban (% of urban population)  \
# 0                                                  45.3
# 1                                                  50.2
# 2                                                  54.7
# 3                                                  59.2
# 4                                                  62.9
# ...                                                 ...
# 4057                                               79.6
# 4058                                               79.2
# 4059                                               79.2
# 4060                                               78.8
# 4061                                               78.8
#
#       Access to electricity (% of population)  \
# 0                                        23.8
# 1                                        28.7
# 2                                        33.5
# 3                                        38.4
# 4                                        42.4
# ...                                       ...
# 4057                                     33.7
# 4058                                     42.5
# 4059                                     44.0
# 4060                                     45.4
# 4061                                     46.7
#
#       Access to electricity, rural (% of rural population)  \
# 0                                                   7.8
# 1                                                  15.4
# 2                                                  19.3
# 3                                                  25.0
# 4                                                  28.0
# ...                                                 ...
# 4057                                               10.9
# 4058                                               21.9
# 4059                                               24.2
# 4060                                               26.4
# 4061                                               28.3
#
#       Access to electricity, urban (% of urban population)  ...  \
# 0                                                  78.8     ...
# 1                                                  74.0     ...
# 2                                                  81.6     ...
# 3                                                  83.0     ...
# 4                                                  89.9     ...
# ...                                                 ...     ...
# 4057                                               81.2     ...
# 4058                                               85.5     ...
# 4059                                               85.5     ...
# 4060                                               85.4     ...
# 4061                                               85.4     ...
#
#       Voice and Accountability: Percentile Rank  \
# 0                                     15.384615
# 1                                     14.903846
# 2                                     17.788462
# 3                                     18.750000
# 4                                     14.423077
# ...                                         ...
# 4057                                  15.763547
# 4058                                  14.778325
# 4059                                  14.778325
# 4060                                  16.990292
# 4061                                  16.425121
#
#       Voice and Accountability: Percentile Rank, Lower Bound of 90% Confidence Interval  \
# 0                                              7.211538
# 1                                              8.173077
# 2                                              8.653846
# 3                                             10.096154
# 4                                              9.134615
# ...                                                 ...
# 4057                                           9.852217
# 4058                                           9.852217
# 4059                                          10.837439
# 4060                                          12.135922
# 4061                                          12.077294
#
#       Voice and Accountability: Percentile Rank, Upper Bound of 90% Confidence Interval  \
# 0                                             21.634615
# 1                                             23.557692
# 2                                             25.000000
# 3                                             25.000000
# 4                                             21.634615
# ...                                                 ...
# 4057                                          22.167488
# 4058                                          22.167488
# 4059                                          21.674877
# 4060                                          21.844660
# 4061                                          21.256039
#
#       Voice and Accountability: Standard Error  \
# 0                                     0.175590
# 1                                     0.173295
# 2                                     0.150166
# 3                                     0.145505
# 4                                     0.143899
# ...                                        ...
# 4057                                  0.121550
# 4058                                  0.119329
# 4059                                  0.119707
# 4060                                  0.123724
# 4061                                  0.117815
#
#       Wanted fertility rate (births per woman)  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 4057                                       3.6
# 4058                                       NaN
# 4059                                       NaN
# 4060                                       NaN
# 4061                                       NaN
#
#       Water productivity, total (constant 2015 US$ GDP per cubic meter of total freshwater withdrawal)  \
# 0                                              0.393379
# 1                                              0.437554
# 2                                              0.460996
# 3                                              0.524735
# 4                                              0.545331
# ...                                                 ...
# 4057                                           5.880153
# 4058                                           5.920923
# 4059                                           6.278786
# 4060                                           5.837430
# 4061                                           5.467778
#
#       Women who were first married by age 15 (% of women ages 20-24)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4057                                                3.7
# 4058                                                NaN
# 4059                                                NaN
# 4060                                                NaN
# 4061                                                5.4
#
#       Women who were first married by age 18 (% of women ages 20-24)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4057                                               32.4
# 4058                                                NaN
# 4059                                                NaN
# 4060                                                NaN
# 4061                                               33.7
#
#       Women's share of population ages 15+ living with HIV (%)  \
# 0                                             27.748782
# 1                                             27.946238
# 2                                             28.204330
# 3                                             28.465089
# 4                                             28.686173
# ...                                                 ...
# 4057                                          59.740456
# 4058                                          59.888983
# 4059                                          60.053623
# 4060                                          60.216147
# 4061                                          60.377610
#
#       Young people (ages 15-24) newly infected with HIV
# 0                                                 500.0
# 1                                                 500.0
# 2                                                 500.0
# 3                                                 500.0
# 4                                                 500.0
# ...                                                 ...
# 4057                                            16000.0
# 4058                                            14000.0
# 4059                                            11000.0
# 4060                                             8400.0
# 4061                                             6900.0
#
# [3824 rows x 931 columns]

# %% [markdown]
# Create list of catagories

# %%
print(df.shape)

cats=pd.DataFrame(df.columns.values)
cats.drop(1)

cats.to_csv('Series_names.csv')
# type(cats)
print(cats)
# Out:
# (3824, 931)
#                                                      0
# 0                                           Unnamed: 0
# 1                                         Country Name
# 2                                                 Year
# 3    ARI treatment (% of children under 5 taken to ...
# 4    Access to clean fuels and technologies for coo...
# ..                                                 ...
# 926  Water productivity, total (constant 2015 US$ G...
# 927  Women who were first married by age 15 (% of w...
# 928  Women who were first married by age 18 (% of w...
# 929  Women's share of population ages 15+ living wi...
# 930  Young people (ages 15-24) newly infected with HIV
#
# [931 rows x 1 columns]

# %% [markdown]
# Remove un-wanted index column

# %%
df=df.drop('Unnamed: 0',1)
df.shape
# Out:
# /var/folders/8j/2xw6vvr51bsczxp4p37711lx24bqhv/T/ipykernel_26900/610499963.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df=df.drop('Unnamed: 0',1)
# (3824, 930)

# %% [markdown]
# Testing looking up one country and one year

# %%
afganisatan=df[(df['Country Name']=='Afghanistan')&(df['Year']==2008)]
print(afganisatan)
# Out:
#   Country Name  Year  \
# 4  Afghanistan  2008
#
#    ARI treatment (% of children under 5 taken to a health provider)  \
# 4                                                NaN
#
#    Access to clean fuels and technologies for cooking (% of population)  \
# 4                                               16.6
#
#    Access to clean fuels and technologies for cooking, rural (% of rural population)  \
# 4                                                4.3
#
#    Access to clean fuels and technologies for cooking, urban (% of urban population)  \
# 4                                               62.9
#
#    Access to electricity (% of population)  \
# 4                                     42.4
#
#    Access to electricity, rural (% of rural population)  \
# 4                                               28.0
#
#    Access to electricity, urban (% of urban population)  \
# 4                                               89.9
#
#    Adjusted net enrollment rate, primary (% of primary school age children)  \
# 4                                                NaN
#
#    ...  Voice and Accountability: Percentile Rank  \
# 4  ...                                  14.423077
#
#    Voice and Accountability: Percentile Rank, Lower Bound of 90% Confidence Interval  \
# 4                                           9.134615
#
#    Voice and Accountability: Percentile Rank, Upper Bound of 90% Confidence Interval  \
# 4                                          21.634615
#
#    Voice and Accountability: Standard Error  \
# 4                                  0.143899
#
#    Wanted fertility rate (births per woman)  \
# 4                                       NaN
#
#    Water productivity, total (constant 2015 US$ GDP per cubic meter of total freshwater withdrawal)  \
# 4                                           0.545331
#
#    Women who were first married by age 15 (% of women ages 20-24)  \
# 4                                                NaN
#
#    Women who were first married by age 18 (% of women ages 20-24)  \
# 4                                                NaN
#
#    Women's share of population ages 15+ living with HIV (%)  \
# 4                                          28.686173
#
#    Young people (ages 15-24) newly infected with HIV
# 4                                              500.0
#
# [1 rows x 930 columns]

# %%
countries=df['Country Name'].unique()
corrlist=pd.DataFrame(df['Country Name'].unique())
corrlist.columns=['Country Name']
co2_gdp_cor=[]
co2_pop_cor=[]
gdp_pop_cor=[]


for count in countries:
    cor=df[(df['Country Name']==count)]['CO2 emissions (kt)'].corr(df[(df['Country Name']==count)]['GDP (current US$)'])
    co2_gdp_cor.append(cor)

corrlist['CO2/GDP']=co2_gdp_cor

for count in countries:
    cor=df[(df['Country Name']==count)]['CO2 emissions (kt)'].corr(df[(df['Country Name']==count)]['Population, total'])
    co2_pop_cor.append(cor)

corrlist['CO2/Pop']=co2_pop_cor

for count in countries:
    cor=df[(df['Country Name']==count)]['GDP (current US$)'].corr(df[(df['Country Name']==count)]['Population, total'])
    gdp_pop_cor.append(cor)

corrlist['GDP/Pop']=gdp_pop_cor

corrlist
# Out:
#                     Country Name   CO2/GDP   CO2/Pop   GDP/Pop
# 0                    Afghanistan  0.953843  0.845380  0.843792
# 1    Africa Eastern and Southern  0.911996  0.967521  0.863912
# 2     Africa Western and Central  0.791936  0.952544  0.851145
# 3                        Albania  0.728934 -0.799527 -0.892734
# 4                        Algeria  0.694246  0.990865  0.658552
# ..                           ...       ...       ...       ...
# 234                     Viet Nam  0.950888  0.947778  0.995398
# 235                        World  0.991377  0.963222  0.959106
# 236                  Yemen, Rep.  0.144301 -0.633956  0.580068
# 237                       Zambia  0.687603  0.954729  0.814469
# 238                     Zimbabwe  0.567106  0.376762  0.891280
#
# [239 rows x 4 columns]
