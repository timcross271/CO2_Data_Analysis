# %% [markdown]
# ### CO2 data cleaning
#
# Cleaned the data ready for further analysis. Removed variables with insufficient data, and countries with insufficient data. Also restructured the data using melt and pivot to allow for easier analysis.

# %% [markdown]
# Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as pl

# %% [markdown]
# Load data file into a dataframe

# %%
df=pd.read_csv('Data/Merged_Combined_data.csv')

# %% [markdown]
# Remove unneeded columns

# %%
df_reduced=df.drop(['Unnamed: 0','Series Code','Country Code','2021 [YR2021]','2022 [YR2022]','2023 [YR2023]'],axis='columns')

# %% [markdown]
# Get all unique series names

# %%
series=df_reduced['Series Name'].unique()
series=np.array(series)
series.shape
# Out:
# (934,)

# %% [markdown]
# Change all empty cells to nan.

# %%
(df_reduced[df_reduced.eq('..')])=np.nan
df_reduced.to_csv('Data/data_reduced.csv')

# %% [markdown]
# Melt data to new layout. Year was previously spread over multiple columns, melt to reduce year to one column.

# %%
df_melt = df_reduced.melt(id_vars=['Series Name','Country Name'], var_name='Year',value_name='Value') 
df_melt = df_melt.sort_values(by=['Country Name', 'Year']) # Sort by country name and then year
df_melt=df_melt.reset_index(drop=True) # Re index the new sorted data

# %%
df_melt
# Out:
#                                                Series Name Country Name  \
# 0        Access to clean fuels and technologies for coo...  Afghanistan
# 1        Access to clean fuels and technologies for coo...  Afghanistan
# 2        Access to clean fuels and technologies for coo...  Afghanistan
# 3                  Access to electricity (% of population)  Afghanistan
# 4        Access to electricity, rural (% of rural popul...  Afghanistan
# ...                                                    ...          ...
# 4210164                                                NaN          NaN
# 4210165                                                NaN          NaN
# 4210166                                                NaN          NaN
# 4210167   Data from database: World Development Indicators          NaN
# 4210168                           Last Updated: 06/28/2024          NaN
#
#                   Year Value
# 0        2004 [YR2004]  10.5
# 1        2004 [YR2004]   1.9
# 2        2004 [YR2004]  45.3
# 3        2004 [YR2004]  23.8
# 4        2004 [YR2004]   7.8
# ...                ...   ...
# 4210164  2020 [YR2020]   NaN
# 4210165  2020 [YR2020]   NaN
# 4210166  2020 [YR2020]   NaN
# 4210167  2020 [YR2020]   NaN
# 4210168  2020 [YR2020]   NaN
#
# [4210169 rows x 4 columns]

# %% [markdown]
# Change all years to integers

# %%
df_melt['Year']=df_melt['Year'].str[0:4].astype(int)
df_melt
# Out:
#                                                Series Name Country Name  Year  \
# 0        Access to clean fuels and technologies for coo...  Afghanistan  2004
# 1        Access to clean fuels and technologies for coo...  Afghanistan  2004
# 2        Access to clean fuels and technologies for coo...  Afghanistan  2004
# 3                  Access to electricity (% of population)  Afghanistan  2004
# 4        Access to electricity, rural (% of rural popul...  Afghanistan  2004
# ...                                                    ...          ...   ...
# 4210164                                                NaN          NaN  2020
# 4210165                                                NaN          NaN  2020
# 4210166                                                NaN          NaN  2020
# 4210167   Data from database: World Development Indicators          NaN  2020
# 4210168                           Last Updated: 06/28/2024          NaN  2020
#
#         Value
# 0        10.5
# 1         1.9
# 2        45.3
# 3        23.8
# 4         7.8
# ...       ...
# 4210164   NaN
# 4210165   NaN
# 4210166   NaN
# 4210167   NaN
# 4210168   NaN
#
# [4210169 rows x 4 columns]

# %% [markdown]
# Reorder Columns by Country

# %%
df_melt=df_melt.reindex(columns=['Country Name','Year','Series Name','Value'])

# %% [markdown]
# Pivot Data to move variables from rows to columns

# %%
# df_pivot=df_melt.pivot(index='County Name', columns='Year',values='Value')
df_pivot = df_melt.pivot_table(values='Value', index=['Country Name','Year'], columns='Series Name',aggfunc='min')
df_pivot.reset_index(inplace=True)
df_pivot.columns.name = None
# df_melt = df_melt.sort_values(by=['Country Name', 'Year']) # Sort by country name and then year
# df_melt=df_melt.reset_index(drop=True) # Re index the new sorted data

# %%
df_pivot.to_csv('Data/CO2_pivot_930.csv')
df_pivot.shape
df_pivot
# Out:
#      Country Name  Year  \
# 0     Afghanistan  2004
# 1     Afghanistan  2005
# 2     Afghanistan  2006
# 3     Afghanistan  2007
# 4     Afghanistan  2008
# ...           ...   ...
# 4500     Zimbabwe  2016
# 4501     Zimbabwe  2017
# 4502     Zimbabwe  2018
# 4503     Zimbabwe  2019
# 4504     Zimbabwe  2020
#
#      ARI treatment (% of children under 5 taken to a health provider)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4500                                                NaN
# 4501                                                NaN
# 4502                                                NaN
# 4503                                                 48
# 4504                                                NaN
#
#      Access to clean fuels and technologies for cooking (% of population)  \
# 0                                                  10.5
# 1                                                  11.9
# 2                                                  13.5
# 3                                                  15.1
# 4                                                  16.6
# ...                                                 ...
# 4500                                                 30
# 4501                                               30.1
# 4502                                               30.3
# 4503                                               30.3
# 4504                                               30.5
#
#      Access to clean fuels and technologies for cooking, rural (% of rural population)  \
# 0                                                   1.9
# 1                                                   2.4
# 2                                                     3
# 3                                                   3.6
# 4                                                   4.3
# ...                                                 ...
# 4500                                                  6
# 4501                                                6.1
# 4502                                                6.5
# 4503                                                6.7
# 4504                                                6.9
#
#      Access to clean fuels and technologies for cooking, urban (% of urban population)  \
# 0                                                  45.3
# 1                                                  50.2
# 2                                                  54.7
# 3                                                  59.2
# 4                                                  62.9
# ...                                                 ...
# 4500                                               79.2
# 4501                                               79.2
# 4502                                               78.8
# 4503                                               78.8
# 4504                                               78.6
#
#      Access to electricity (% of population)  \
# 0                                       23.8
# 1                                       28.7
# 2                                       33.5
# 3                                       38.4
# 4                                       42.4
# ...                                      ...
# 4500                                    42.5
# 4501                                      44
# 4502                                    45.4
# 4503                                    46.7
# 4504                                    52.7
#
#      Access to electricity, rural (% of rural population)  \
# 0                                                   7.8
# 1                                                  15.4
# 2                                                  19.3
# 3                                                    25
# 4                                                    28
# ...                                                 ...
# 4500                                               21.9
# 4501                                               24.2
# 4502                                               26.4
# 4503                                               28.3
# 4504                                               37.1
#
#      Access to electricity, urban (% of urban population)  \
# 0                                                  78.8
# 1                                                    74
# 2                                                  81.6
# 3                                                    83
# 4                                                  89.9
# ...                                                 ...
# 4500                                               85.5
# 4501                                               85.5
# 4502                                               85.4
# 4503                                               85.4
# 4504                                               85.7
#
#      Adjusted net enrollment rate, primary (% of primary school age children)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4500                                                NaN
# 4501                                                NaN
# 4502                                                NaN
# 4503                                                NaN
# 4504                                                NaN
#
#       ... Voice and Accountability: Percentile Rank  \
# 0     ...                           15.384614944458
# 1     ...                          14.9038457870483
# 2     ...                          17.7884616851807
# 3     ...                                     18.75
# 4     ...                          14.4230766296387
# ...   ...                                       ...
# 4500  ...                          14.7783250808716
# 4501  ...                          14.7783250808716
# 4502  ...                           16.990291595459
# 4503  ...                           16.425121307373
# 4504  ...                          17.8743953704834
#
#      Voice and Accountability: Percentile Rank, Lower Bound of 90% Confidence Interval  \
# 0                                      7.21153831481934
# 1                                      8.17307662963867
# 2                                      8.65384578704834
# 3                                      10.0961542129517
# 4                                      9.13461494445801
# ...                                                 ...
# 4500                                   9.85221672058105
# 4501                                    10.837438583374
# 4502                                   12.1359224319458
# 4503                                   12.0772943496704
# 4504                                    13.043478012085
#
#      Voice and Accountability: Percentile Rank, Upper Bound of 90% Confidence Interval  \
# 0                                       21.634614944458
# 1                                      23.5576915740967
# 2                                                    25
# 3                                                    25
# 4                                       21.634614944458
# ...                                                 ...
# 4500                                   22.1674880981445
# 4501                                    21.674877166748
# 4502                                   21.8446598052979
# 4503                                   21.2560386657715
# 4504                                   23.1884059906006
#
#      Voice and Accountability: Standard Error  \
# 0                            0.17559015750885
# 1                           0.173295274376869
# 2                           0.150166392326355
# 3                           0.145505249500275
# 4                           0.143898978829384
# ...                                       ...
# 4500                        0.119328863918781
# 4501                        0.119706504046917
# 4502                        0.123724415898323
# 4503                        0.117814749479294
# 4504                        0.120229728519917
#
#      Wanted fertility rate (births per woman)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 4500                                      NaN
# 4501                                      NaN
# 4502                                      NaN
# 4503                                      NaN
# 4504                                      NaN
#
#      Water productivity, total (constant 2015 US$ GDP per cubic meter of total freshwater withdrawal)  \
# 0                                     0.393379136257915
# 1                                      0.43755449144972
# 2                                     0.460996049984167
# 3                                     0.524734836954617
# 4                                     0.545330594402961
# ...                                                 ...
# 4500                                    5.9209228137323
# 4501                                    6.2787859030648
# 4502                                   5.83743042524569
# 4503                                   5.46777827201913
# 4504                                    5.0403647430182
#
#      Women who were first married by age 15 (% of women ages 20-24)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4500                                                NaN
# 4501                                                NaN
# 4502                                                NaN
# 4503                                                5.4
# 4504                                                NaN
#
#      Women who were first married by age 18 (% of women ages 20-24)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4500                                                NaN
# 4501                                                NaN
# 4502                                                NaN
# 4503                                               33.7
# 4504                                                NaN
#
#      Women's share of population ages 15+ living with HIV (%)  \
# 0                                      27.7487821851079
# 1                                      27.9462383215866
# 2                                      28.2043295436848
# 3                                      28.4650885812119
# 4                                      28.6861732644865
# ...                                                 ...
# 4500                                   59.8889834645066
# 4501                                   60.0536229593552
# 4502                                   60.2161468471976
# 4503                                   60.3776096269848
# 4504                                   60.5516086911776
#
#      Young people (ages 15-24) newly infected with HIV
# 0                                                  500
# 1                                                  500
# 2                                                  500
# 3                                                  500
# 4                                                  500
# ...                                                ...
# 4500                                             14000
# 4501                                             11000
# 4502                                              8400
# 4503                                              6900
# 4504                                              5900
#
# [4505 rows x 930 columns]

# %% [markdown]
# Find all series covering CO2

# %%
series=df_pivot.columns
for text in series:
    if 'CO2' in text:
        print(text)
# Out:
# Agricultural methane emissions (thousand metric tons of CO2 equivalent)
# Agricultural nitrous oxide emissions (thousand metric tons of CO2 equivalent)
# CO2 emissions (kg per 2015 US$ of GDP)
# CO2 emissions (kg per 2021 PPP $ of GDP)
# CO2 emissions (kg per PPP $ of GDP)
# CO2 emissions (kt)
# CO2 emissions (metric tons per capita)
# CO2 emissions from electricity and heat production, total (% of total fuel combustion)
# CO2 emissions from gaseous fuel consumption (% of total)
# CO2 emissions from gaseous fuel consumption (kt)
# CO2 emissions from liquid fuel consumption (% of total)
# CO2 emissions from liquid fuel consumption (kt)
# CO2 emissions from manufacturing industries and construction (% of total fuel combustion)
# CO2 emissions from other sectors, excluding residential buildings and commercial and public services (% of total fuel combustion)
# CO2 emissions from residential buildings and commercial and public services (% of total fuel combustion)
# CO2 emissions from solid fuel consumption (% of total)
# CO2 emissions from solid fuel consumption (kt)
# CO2 emissions from transport (% of total fuel combustion)
# CO2 intensity (kg per kg of oil equivalent energy use)
# GHG net emissions/removals by LUCF (Mt of CO2 equivalent)
# HFC gas emissions (thousand metric tons of CO2 equivalent)
# Methane emissions (kt of CO2 equivalent)
# Methane emissions in energy sector (thousand metric tons of CO2 equivalent)
# Nitrous oxide emissions (thousand metric tons of CO2 equivalent)
# Nitrous oxide emissions in energy sector (thousand metric tons of CO2 equivalent)
# Other greenhouse gas emissions, HFC, PFC and SF6 (thousand metric tons of CO2 equivalent)
# PFC gas emissions (thousand metric tons of CO2 equivalent)
# SF6 gas emissions (thousand metric tons of CO2 equivalent)
# Total greenhouse gas emissions (kt of CO2 equivalent)

# %% [markdown]
# Removing countries with no CO2 data

# %%
no_co2=df_pivot[df_pivot['CO2 emissions (kt)'].isnull()]
no_co2
print(no_co2['Country Name'].unique())


df_pivot2=df_pivot.dropna(subset=["CO2 emissions (kt)"])
df_pivot2['Country Name'].unique()

print(df_pivot2.shape)

df_pivot2.to_csv('Data/CO2_pivot_noCO2_930.csv')
# Out:
# ['American Samoa' 'Aruba' 'Bermuda' 'British Virgin Islands'
#  'Cayman Islands' 'Channel Islands' 'Curacao' 'Faroe Islands'
#  'French Polynesia' 'Gibraltar' 'Greenland' 'Guam' 'Hong Kong SAR, China'
#  'Isle of Man' 'Kosovo' 'Macao SAR, China' 'Monaco' 'New Caledonia'
#  'Northern Mariana Islands' 'Puerto Rico' 'San Marino'
#  'Sint Maarten (Dutch part)' 'St. Martin (French part)'
#  'Turks and Caicos Islands' 'Virgin Islands (U.S.)' 'West Bank and Gaza']
# (4063, 930)

# %% [markdown]
# Remove countries with insufficient data.

# %%
df_pivot4=df_pivot2.dropna(thresh=len(df_pivot2.index), axis=0)

# %% [markdown]
# Remove series with insufficent data

# %%
df_pivot3=df_pivot2.dropna(thresh=len(df_pivot2.index)/1.01, axis=1)
df_pivot3.to_csv('Data/CO2_pivot_noCO2_insfData_120.csv')
df_pivot3.shape
# Out:
# (4063, 120)
